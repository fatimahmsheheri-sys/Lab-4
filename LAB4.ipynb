# %%
import micropip
await micropip.install("seaborn")

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")

pd.set_option("display.max_columns", None)

df = pd.read_csv("student-mat.csv", sep=";")
df.head(10)
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0     GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1     GP   F   17       U     GT3       T     1     1   at_home     other
# 2     GP   F   15       U     LE3       T     1     1   at_home     other
# 3     GP   F   15       U     GT3       T     4     2    health  services
# 4     GP   F   16       U     GT3       T     3     3     other     other
# 5     GP   M   16       U     LE3       T     4     3  services     other
# 6     GP   M   16       U     LE3       T     2     2     other     other
# 7     GP   F   17       U     GT3       A     4     4     other   teacher
# 8     GP   M   15       U     LE3       A     3     2  services     other
# 9     GP   M   15       U     GT3       T     3     4     other     other
#
#        reason guardian  traveltime  studytime  failures schoolsup famsup paid  \
# ...

# %%
df.dtypes
# Out:
# school          str
# sex             str
# age           int64
# address         str
# famsize         str
# Pstatus         str
# Medu          int64
# Fedu          int64
# Mjob            str
# Fjob            str
# reason          str
# guardian        str
# traveltime    int64
# studytime     int64
# failures      int64
# schoolsup       str
# famsup          str
# paid            str
# activities      str
# nursery         str
# higher          str
# internet        str
# romantic        str
# famrel        int64
# freetime      int64
# goout         int64
# Dalc          int64
# Walc          int64
# health        int64
# absences      int64
# G1            int64
# G2            int64
# G3            int64
# dtype: object

# %%
df.isna().sum()
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %%
df_missing = df.copy()
df_missing.loc[0:5, 'absences'] = np.nan
df_missing.isna().sum()
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      6
# G1            0
# G2            0
# G3            0
# dtype: int64

# %%
df_removed = df_missing.dropna()
df_removed.shape
# Out:
# (389, 33)

# %%
df_imputed_mean = df_missing.copy()

mean_value = df_imputed_mean['absences'].mean()
df_imputed_mean['absences'] = df_imputed_mean['absences'].fillna(mean_value)
df_imputed_mean.isna().sum()
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %%
df_imputed_mean.head(10)
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0     GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1     GP   F   17       U     GT3       T     1     1   at_home     other
# 2     GP   F   15       U     LE3       T     1     1   at_home     other
# 3     GP   F   15       U     GT3       T     4     2    health  services
# 4     GP   F   16       U     GT3       T     3     3     other     other
# 5     GP   M   16       U     LE3       T     4     3  services     other
# 6     GP   M   16       U     LE3       T     2     2     other     other
# 7     GP   F   17       U     GT3       A     4     4     other   teacher
# 8     GP   M   15       U     LE3       A     3     2  services     other
# 9     GP   M   15       U     GT3       T     3     4     other     other
#
#        reason guardian  traveltime  studytime  failures schoolsup famsup paid  \
# ...

# %%
df_imputed_median = df_missing.copy()

median_value = df_imputed_median['absences'].median()
df_imputed_median['absences'] = df_imputed_median['absences'].fillna(median_value)
df_imputed_median.isna().sum()
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %%
df_imputed_median.head(10)
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0     GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1     GP   F   17       U     GT3       T     1     1   at_home     other
# 2     GP   F   15       U     LE3       T     1     1   at_home     other
# 3     GP   F   15       U     GT3       T     4     2    health  services
# 4     GP   F   16       U     GT3       T     3     3     other     other
# 5     GP   M   16       U     LE3       T     4     3  services     other
# 6     GP   M   16       U     LE3       T     2     2     other     other
# 7     GP   F   17       U     GT3       A     4     4     other   teacher
# 8     GP   M   15       U     LE3       A     3     2  services     other
# 9     GP   M   15       U     GT3       T     3     4     other     other
#
#        reason guardian  traveltime  studytime  failures schoolsup famsup paid  \
# ...

# %%
plt.figure(figsize=(4,3))
sns.boxplot(x=df['absences'])
plt.title("Boxplot of Absences")
plt.show()

# %%
Q1 = df['absences'].quantile(0.25)
Q3 = df['absences'].quantile(0.75)
IQR = Q3 - Q1

lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

outliers = df[(df['absences'] < lower) | (df['absences'] > upper)]
outliers.shape
# Out:
# (15, 33)

# %%
outliers.head(15)
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 40      GP   F   16       U     LE3       T     2     2     other     other
# 74      GP   F   16       U     GT3       T     3     3     other  services
# 103     GP   F   15       U     GT3       T     3     2  services     other
# 183     GP   F   17       U     LE3       T     3     3     other     other
# 198     GP   F   17       U     GT3       T     4     4  services   teacher
# 205     GP   F   17       U     GT3       T     3     4   at_home  services
# 216     GP   F   17       U     GT3       T     4     3     other     other
# 260     GP   F   18       U     GT3       T     4     3  services     other
# 276     GP   F   18       R     GT3       A     3     2     other  services
# 277     GP   M   18       U     GT3       T     4     4   teacher  services
# 280     GP   M   17       U     LE3       A     4     1  services     other
# ...

# %%
df_no_outliers = df[(df['absences'] >= lower) & (df['absences'] <= upper)]
print("Original shape: ", df.shape)
print("After removing outliers: ", df_no_outliers.shape)
# Out:
# Original shape:  (395, 33)
# After removing outliers:  (380, 33)

# %%
lower_cap = df['absences'].quantile(0.05)
upper_cap = df['absences'].quantile(0.95)

df_capped = df.copy()
df_capped['absences'] = df_capped['absences'].clip(lower_cap, upper_cap)

# %%
df[['absences', 'G3']].head()
# Out:
#    absences  G3
# 0         6   6
# 1         4   6
# 2        10  10
# 3         2  15
# 4         4  10

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
df_scaled = df[['absences', 'G3']].copy()

df_scaled[['absences', 'G3']] = scaler.fit_transform(df_scaled)

df_scaled.head()
# Out:
#    absences    G3
# 0  0.080000  0.30
# 1  0.053333  0.30
# 2  0.133333  0.50
# 3  0.026667  0.75
# 4  0.053333  0.50

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
df_standardized = df[['absences', 'G3']].copy()

df_standardized[['absences', 'G3']] = scaler.fit_transform(df_standardized)

df_standardized.head()
# Out:
#    absences        G3
# 0  0.036424 -0.964934
# 1 -0.213796 -0.964934
# 2  0.536865 -0.090739
# 3 -0.464016  1.002004
# 4 -0.213796 -0.090739

# %%
plt.figure(figsize=(6,4))
sns.heatmap(df_standardized[['absences','G3']].corr(),
            annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap (Before PCA)")
plt.show()

# %%
from sklearn.decomposition import PCA

X = df_standardized[['absences', 'G3']]

pca = PCA(n_components=2)
principal_components = pca.fit_transform(X)

pca.explained_variance_ratio_
# Out:
# array([0.51712366, 0.48287634])

# %%
plt.figure(figsize=(6,4))
plt.scatter(principal_components[:,0], principal_components[:,1])
plt.title("PCA Projection")
plt.xlabel("Principal Component 1")
plt.ylabel("Principal Component 2")
plt.show()
